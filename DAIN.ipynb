# %% [markdown]
# ### Optimizing Time Series Forecasting: A Comparative Study of Adam and Nesterov Accelerated Gradient on LSTM and GRU networks Using Stock Market data - Experiments Code

# %% [markdown]
# ## Step 1: Libary Imports

# %%
# Import necessary libraries for data
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tabulate import tabulate
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

import yfinance as yf
from datetime import datetime

# Define the stock ticker and date range
stock_ticker = 'AAPL'
start_date = '2014-01-01'
end_date = '2024-08-01'

# %% [markdown]
# ## Step 2: Data Preparation and Splitting

# %% [markdown]
# ### Proposed DAIN

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F

class DAIN_Layer(nn.Module):
    def __init__(self, mode='full', isTarget=False, mean_lr=0.00001, gate_lr=0.001, scale_lr=0.00001, input_dim=144):
        super(DAIN_Layer, self).__init__()
        self.mode = mode
        self.isTarget = isTarget
        self.mean_lr = mean_lr
        self.gate_lr = gate_lr
        self.scale_lr = scale_lr
        self.mean_layer = nn.Linear(input_dim, input_dim, bias=False)
        self.mean_layer.weight.data = torch.FloatTensor(data=np.eye(input_dim, input_dim))
        self.scaling_layer = nn.Linear(input_dim, input_dim, bias=False)
        self.scaling_layer.weight.data = torch.FloatTensor(data=np.eye(input_dim, input_dim))
        self.gating_layer = nn.Linear(input_dim, input_dim)
        self.eps = 1e-8

    def forward(self, x):
        if self.mode == 'full':
           # Step 1:
            avg = torch.mean(x, 2)
            adaptive_avg = self.mean_layer(avg)
            adaptive_avg = adaptive_avg.reshape(adaptive_avg.size(0), adaptive_avg.size(1), 1)
            x = x - adaptive_avg

            # # Step 2:
            std = torch.mean(x ** 2, 2)
            std = torch.sqrt(std + self.eps)
            adaptive_std = self.scaling_layer(std)
            adaptive_std[adaptive_std <= self.eps] = 1

            adaptive_std = adaptive_std.reshape(adaptive_std.size(0), adaptive_std.size(1), 1)
            x = x / adaptive_std

            # Step 3: 
            avg = torch.mean(x, 2)
            gate = F.sigmoid(self.gating_layer(avg))
            gate = gate.reshape(gate.size(0), gate.size(1), 1)
            x = x * gate
        else:
            raise ValueError("Unknown mode")

        if self.isTarget:
            return x, adaptive_avg, adaptive_std, gate
        else: 
            return x

# %%
def inverse_dain(data, adaptive_avg, adaptive_std, gate):
    """
    Inverse of the adaptive_scale operation.

    Args:
        data:           pd.DataFrame  (n_samples, n_features)
                        torch.Tensor  (batch_size, 1, n_features) from DataLoader
                        np.ndarray    (n_samples, n_features)
        adaptive_avg:   tensor from dain forward pass, shape (1, n_features, 1)
        adaptive_std:   tensor from dain forward pass, shape (1, n_features, 1)

    Returns:
        Same type as input — pd.DataFrame, torch.Tensor, or np.ndarray
    """
    if isinstance(data, pd.DataFrame):
        cols, idx = data.columns, data.index
        x = torch.tensor(data.values, dtype=torch.float32).T.unsqueeze(0)
        x = x / gate
        x = (x * adaptive_std) + adaptive_avg
        x = x.squeeze(0).T.numpy()
        return pd.DataFrame(x, columns=cols, index=idx)

    elif isinstance(data, torch.Tensor):
        x = data.squeeze(1).T.unsqueeze(0)   # (1, n_features, batch_size)
        x = x / gate
        x = (x * adaptive_std) + adaptive_avg
        return x.squeeze(0).T.unsqueeze(1)    # (batch_size, 1, n_features)

    elif isinstance(data, np.ndarray):
        was_1d = data.ndim == 1
        if was_1d:
            data = data.reshape(-1, 1)
        x = torch.tensor(data, dtype=torch.float32).T.unsqueeze(0)
        x = x / gate
        x = (x * adaptive_std) + adaptive_avg
        result = x.squeeze(0).T.numpy()
        if was_1d:
            result = result.ravel()
        return result

    else:
        raise TypeError(f"Expected pd.DataFrame, torch.Tensor, or np.ndarray, got {type(data)}")

# %%
def apply_dain(df, dain):  
    cols = df.columns
    idx = df.index
    x = torch.tensor(df.values, dtype=torch.float32)
    x = x.T.unsqueeze(0)
    with torch.no_grad():
        result = dain(x) 
    if dain.isTarget:
        normalized, adaptive_avg, adaptive_std, gate = result
        normalized = normalized.squeeze(0).T.numpy()
        return pd.DataFrame(normalized, columns=cols, index=idx), adaptive_avg, adaptive_std, gate
    else:
        normalized = result.squeeze(0).T.numpy()
        return pd.DataFrame(normalized, columns=cols, index=idx)

# %%
df = yf.download(stock_ticker, start=start_date, end=end_date, multi_level_index=False)

# Filters the 'Close' column
data = df.filter(['Close'])
data
# Out:
# /tmp/ipykernel_24/4001820110.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock_ticker, start=start_date, end=end_date, multi_level_index=False)
# [*********************100%***********************]  1 of 1 completed
#                  Close
# Date
# 2014-01-02   17.124884
# 2014-01-03   16.748732
# 2014-01-06   16.840046
# 2014-01-07   16.719620
# 2014-01-08   16.825506
# ...                ...
# 2024-07-25  215.622177
# 2024-07-26  216.088165
# 2024-07-29  216.365753
# 2024-07-30  216.920914
# 2024-07-31  220.172760
#
# [2662 rows x 1 columns]

# %%
# Convert the dataframe to a numpy array
dataset = data.values

# Split the dataset into training, validation, and test sets
training_data_len = int(np.ceil(len(dataset) * 0.70))
validation_data_len = int(np.ceil(len(dataset) * 0.85))

train_data = dataset[:training_data_len, :]
val_data = dataset[training_data_len:validation_data_len, :]
test_data = dataset[validation_data_len:, :]

print(f"Training Data Length: {len(train_data)}")
print(f"Validation Data Length: {len(val_data)}")
print(f"Test Data Length: {len(test_data)}")
# Out:
# Training Data Length: 1864
# Validation Data Length: 399
# Test Data Length: 399

# %%
train_data
# Out:
# array([[ 17.12488365],
#        [ 16.74873161],
#        [ 16.84004593],
#        ...,
#        [123.69600677],
#        [123.6472702 ],
#        [122.11691284]], shape=(1864, 1))

# %% [markdown]
# Data Scaling

# %%
dain_forward = DAIN_Layer(mode='full', input_dim=1, isTarget=False)
dain_target = DAIN_Layer(mode='full', input_dim=1, isTarget=True)

# %%
scaled_train_data = apply_dain(pd.DataFrame(train_data), dain_forward)
scaled_val_data, val_adaptive_avg, val_adaptive_std, val_gate = apply_dain(pd.DataFrame(val_data), dain_target)
scaled_test_data, test_adaptive_avg, test_adaptive_std, test_gate = apply_dain(pd.DataFrame(test_data), dain_target)

# %%
scaled_train_data, scaled_val_data, scaled_test_data = np.array(scaled_train_data), np.array(scaled_val_data), np.array(scaled_test_data)

# Concatenate splits so validation/test windows can use prior context
full_scaled_data = np.vstack([scaled_train_data, scaled_val_data, scaled_test_data])
train_end = len(scaled_train_data)
val_end = train_end + len(scaled_val_data)

print("Data scaling completed.")
# Out:
# Data scaling completed.

# %% [markdown]
# ## Sequence Construction and Sliding Window Tuning
# Sequences are built from the full scaled series so validation/test windows retain context from prior splits.

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, Dropout
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# training_callbacks = [
#     EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True),
#     ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6)
# ]

EPOCHS = 50
BATCH_SIZE = 32
# Out:
# 2026-07-16 16:25:02.162304: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1784219102.354987      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1784219102.416152      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1784219102.872120      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1784219102.872164      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1784219102.872167      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1784219102.872169      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# ### Sliding Window Hyperparameter Tuning
# We search over candidate lookback windows using a lightweight LSTM on the validation set, then lock in the best window for all model/optimizer comparisons.

# %%
def create_sequences(data, window_size, start_idx, end_idx):
    """Build (X, y) pairs from a contiguous scaled series slice."""
    x, y = [], []
    for i in range(start_idx + window_size, end_idx):
        x.append(data[i - window_size:i, 0])
        y.append(data[i, 0])
    x, y = np.array(x), np.array(y)
    return x.reshape(x.shape[0], x.shape[1], 1), y


def rmse_in_original_scale(y_scaled, y_pred_scaled, adaptive_avg, adaptive_std, adaptive_gate):
    y_true = inverse_dain(y_scaled, adaptive_avg, adaptive_std, adaptive_gate).reshape(-1, 1)
    y_pred = inverse_dain(y_pred_scaled, adaptive_avg, adaptive_std, adaptive_gate).reshape(-1, 1)
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
WINDOW_CANDIDATES = [30, 60, 90, 120]

# %% [markdown]
# ### LSTM Adam Window Tuning

# %%
window_tuning_results_lstm_adam = []
best_window_size_lstm_adam = WINDOW_CANDIDATES[0]
best_window_val_rmse_lstm_adam = float('inf')

# %%
print('Tuning sliding window on validation RMSE...')
for candidate_window in WINDOW_CANDIDATES:
    x_tune_train, y_tune_train = create_sequences(full_scaled_data, candidate_window, 0, train_end)
    x_tune_val, y_tune_val = create_sequences(full_scaled_data, candidate_window, train_end, val_end)

    tune_model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(candidate_window, 1)),
        Dropout(0.2),
        LSTM(32, return_sequences=False),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(1)
    ])
    tune_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    tune_model.fit(
        x_tune_train, y_tune_train,
        validation_data=(x_tune_val, y_tune_val),
        batch_size=32,
        epochs=50,
        verbose=0,
        # callbacks=training_callbacks
    )

    val_predictions = tune_model.predict(x_tune_val, verbose=0)
    candidate_val_rmse = rmse_in_original_scale(y_tune_val, val_predictions, val_adaptive_avg, val_adaptive_std, val_gate)
    window_tuning_results_lstm_adam.append((candidate_window, candidate_val_rmse))
    print(f'  window={candidate_window:3d} -> validation RMSE: {candidate_val_rmse:.4f}')

    if candidate_val_rmse < best_window_val_rmse_lstm_adam:
        best_window_val_rmse_lstm_adam = candidate_val_rmse
        best_window_size_lstm_adam = candidate_window

print(f'\nSelected sliding window: {best_window_size_lstm_adam} (validation RMSE: {best_window_val_rmse_lstm_adam:.4f})')

x_train_lstm_adam, y_train_lstm_adam = create_sequences(full_scaled_data, best_window_size_lstm_adam, 0, train_end)
x_val_lstm_adam, y_val_lstm_adam = create_sequences(full_scaled_data, best_window_size_lstm_adam, train_end, val_end)
x_test_lstm_adam, y_test_lstm_adam = create_sequences(full_scaled_data, best_window_size_lstm_adam, val_end, len(full_scaled_data))

print('Data preparation completed.')
print(f'Train samples: {len(x_train_lstm_adam)}, Val samples: {len(x_val_lstm_adam)}, Test samples: {len(x_test_lstm_adam)}')
# Out:
# Tuning sliding window on validation RMSE...
# I0000 00:00:1784219114.348909      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# I0000 00:00:1784219118.379807      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   window= 30 -> validation RMSE: 4.3245
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 60 -> validation RMSE: 4.4832
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 90 -> validation RMSE: 4.5776
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window=120 -> validation RMSE: 4.6526
#
# Selected sliding window: 30 (validation RMSE: 4.3245)
# Data preparation completed.
# Train samples: 1834, Val samples: 369, Test samples: 369

# %%
# Visualize sliding window tuning results
window_df = pd.DataFrame(window_tuning_results_lstm_adam, columns=['Window Size', 'Validation RMSE'])
plt.figure(figsize=(8, 4))
plt.bar(window_df['Window Size'].astype(str), window_df['Validation RMSE'], color='steelblue')
plt.axhline(best_window_val_rmse_lstm_adam, color='crimson', linestyle='--', label=f'Best: {best_window_size_lstm_adam}')
plt.title('Sliding Window Hyperparameter Tuning — LSTM Adam')
plt.xlabel('Lookback Window (days)')
plt.ylabel('Validation RMSE ($)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### GRU Adam Window Tuning

# %%
window_tuning_results_gru_adam = []
best_window_size_gru_adam = WINDOW_CANDIDATES[0]
best_window_val_rmse_gru_adam = float('inf')

# %%
print('Tuning sliding window on validation RMSE...')
for candidate_window in WINDOW_CANDIDATES:
    x_tune_train, y_tune_train = create_sequences(full_scaled_data, candidate_window, 0, train_end)
    x_tune_val, y_tune_val = create_sequences(full_scaled_data, candidate_window, train_end, val_end)

    tune_model = Sequential([
        GRU(64, return_sequences=True, input_shape=(candidate_window, 1)),
        Dropout(0.2),
        GRU(32, return_sequences=False),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(1)
    ])
    tune_model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
    tune_model.fit(
        x_tune_train, y_tune_train,
        validation_data=(x_tune_val, y_tune_val),
        batch_size=32,
        epochs=50,
        verbose=0,
        # callbacks=training_callbacks
    )

    val_predictions = tune_model.predict(x_tune_val, verbose=0)
    candidate_val_rmse = rmse_in_original_scale(y_tune_val, val_predictions, val_adaptive_avg, val_adaptive_std, val_gate)
    window_tuning_results_gru_adam.append((candidate_window, candidate_val_rmse))
    print(f'  window={candidate_window:3d} -> validation RMSE: {candidate_val_rmse:.4f}')

    if candidate_val_rmse < best_window_val_rmse_gru_adam:
        best_window_val_rmse_gru_adam = candidate_val_rmse
        best_window_size_gru_adam = candidate_window

print(f'\nSelected sliding window: {best_window_size_gru_adam} (validation RMSE: {best_window_val_rmse_gru_adam:.4f})')

x_train_gru_adam, y_train_gru_adam = create_sequences(full_scaled_data, best_window_size_gru_adam, 0, train_end)
x_val_gru_adam, y_val_gru_adam = create_sequences(full_scaled_data, best_window_size_gru_adam, train_end, val_end)
x_test_gru_adam, y_test_gru_adam = create_sequences(full_scaled_data, best_window_size_gru_adam, val_end, len(full_scaled_data))

print('Data preparation completed.')
print(f'Train samples: {len(x_train_gru_adam)}, Val samples: {len(x_val_gru_adam)}, Test samples: {len(x_test_gru_adam)}')
# Out:
# Tuning sliding window on validation RMSE...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 30 -> validation RMSE: 3.5253
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 60 -> validation RMSE: 3.6778
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 90 -> validation RMSE: 3.7020
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window=120 -> validation RMSE: 3.9028
#
# Selected sliding window: 30 (validation RMSE: 3.5253)
# Data preparation completed.
# Train samples: 1834, Val samples: 369, Test samples: 369

# %%
# Visualize sliding window tuning results
window_df = pd.DataFrame(window_tuning_results_gru_adam, columns=['Window Size', 'Validation RMSE'])
plt.figure(figsize=(8, 4))
plt.bar(window_df['Window Size'].astype(str), window_df['Validation RMSE'], color='steelblue')
plt.axhline(best_window_val_rmse_gru_adam, color='crimson', linestyle='--', label=f'Best: {best_window_size_gru_adam}')
plt.title('Sliding Window Hyperparameter Tuning — GRU Adam')
plt.xlabel('Lookback Window (days)')
plt.ylabel('Validation RMSE ($)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### LSTM NAG Window Tuning

# %%
window_tuning_results_lstm_nag = []
best_window_size_lstm_nag = WINDOW_CANDIDATES[0]
best_window_val_rmse_lstm_nag = float('inf')

# %%
print('Tuning sliding window on validation RMSE...')
for candidate_window in WINDOW_CANDIDATES:
    x_tune_train, y_tune_train = create_sequences(full_scaled_data, candidate_window, 0, train_end)
    x_tune_val, y_tune_val = create_sequences(full_scaled_data, candidate_window, train_end, val_end)

    tune_model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(candidate_window, 1)),
        Dropout(0.2),
        LSTM(32, return_sequences=False),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(1)
    ])
    tune_model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9, nesterov=True), loss='mean_squared_error')
    tune_model.fit(
        x_tune_train, y_tune_train,
        validation_data=(x_tune_val, y_tune_val),
        batch_size=32,
        epochs=50,
        verbose=0,
        # callbacks=training_callbacks
    )

    val_predictions = tune_model.predict(x_tune_val, verbose=0)
    candidate_val_rmse = rmse_in_original_scale(y_tune_val, val_predictions, val_adaptive_avg, val_adaptive_std, val_gate)
    window_tuning_results_lstm_nag.append((candidate_window, candidate_val_rmse))
    print(f'  window={candidate_window:3d} -> validation RMSE: {candidate_val_rmse:.4f}')

    if candidate_val_rmse < best_window_val_rmse_lstm_nag:
        best_window_val_rmse_lstm_nag = candidate_val_rmse
        best_window_size_lstm_nag = candidate_window

print(f'\nSelected sliding window: {best_window_size_lstm_nag} (validation RMSE: {best_window_val_rmse_lstm_nag:.4f})')

x_train_lstm_nag, y_train_lstm_nag = create_sequences(full_scaled_data, best_window_size_lstm_nag, 0, train_end)
x_val_lstm_nag, y_val_lstm_nag = create_sequences(full_scaled_data, best_window_size_lstm_nag, train_end, val_end)
x_test_lstm_nag, y_test_lstm_nag = create_sequences(full_scaled_data, best_window_size_lstm_nag, val_end, len(full_scaled_data))

print('Data preparation completed.')
print(f'Train samples: {len(x_train_lstm_nag)}, Val samples: {len(x_val_lstm_nag)}, Test samples: {len(x_test_lstm_nag)}')
# Out:
# Tuning sliding window on validation RMSE...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 30 -> validation RMSE: 5.5963
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 60 -> validation RMSE: 5.7829
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 90 -> validation RMSE: 6.0063
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window=120 -> validation RMSE: 6.4225
#
# Selected sliding window: 30 (validation RMSE: 5.5963)
# Data preparation completed.
# Train samples: 1834, Val samples: 369, Test samples: 369

# %%
# Visualize sliding window tuning results
window_df = pd.DataFrame(window_tuning_results_lstm_nag, columns=['Window Size', 'Validation RMSE'])
plt.figure(figsize=(8, 4))
plt.bar(window_df['Window Size'].astype(str), window_df['Validation RMSE'], color='steelblue')
plt.axhline(best_window_val_rmse_lstm_nag, color='crimson', linestyle='--', label=f'Best: {best_window_size_lstm_nag}')
plt.title('Sliding Window Hyperparameter Tuning — LSTM NAG')
plt.xlabel('Lookback Window (days)')
plt.ylabel('Validation RMSE ($)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### GRU NAG Window Tuning

# %%
window_tuning_results_gru_nag = []
best_window_size_gru_nag = WINDOW_CANDIDATES[0]
best_window_val_rmse_gru_nag = float('inf')

# %%
print('Tuning sliding window on validation RMSE...')
for candidate_window in WINDOW_CANDIDATES:
    x_tune_train, y_tune_train = create_sequences(full_scaled_data, candidate_window, 0, train_end)
    x_tune_val, y_tune_val = create_sequences(full_scaled_data, candidate_window, train_end, val_end)

    tune_model = Sequential([
        GRU(64, return_sequences=True, input_shape=(candidate_window, 1)),
        Dropout(0.2),
        GRU(32, return_sequences=False),
        Dropout(0.2),
        Dense(16, activation='relu'),
        Dense(1)
    ])
    tune_model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.9, nesterov=True), loss='mean_squared_error')
    tune_model.fit(
        x_tune_train, y_tune_train,
        validation_data=(x_tune_val, y_tune_val),
        batch_size=32,
        epochs=50,
        verbose=0,
        # callbacks=training_callbacks
    )

    val_predictions = tune_model.predict(x_tune_val, verbose=0)
    candidate_val_rmse = rmse_in_original_scale(y_tune_val, val_predictions, val_adaptive_avg, val_adaptive_std, val_gate)
    window_tuning_results_gru_nag.append((candidate_window, candidate_val_rmse))
    print(f'  window={candidate_window:3d} -> validation RMSE: {candidate_val_rmse:.4f}')

    if candidate_val_rmse < best_window_val_rmse_gru_nag:
        best_window_val_rmse_gru_nag = candidate_val_rmse
        best_window_size_gru_nag = candidate_window

print(f'\nSelected sliding window: {best_window_size_gru_nag} (validation RMSE: {best_window_val_rmse_gru_nag:.4f})')

x_train_gru_nag, y_train_gru_nag = create_sequences(full_scaled_data, best_window_size_gru_nag, 0, train_end)
x_val_gru_nag, y_val_gru_nag = create_sequences(full_scaled_data, best_window_size_gru_nag, train_end, val_end)
x_test_gru_nag, y_test_gru_nag = create_sequences(full_scaled_data, best_window_size_gru_nag, val_end, len(full_scaled_data))

print('Data preparation completed.')
print(f'Train samples: {len(x_train_gru_nag)}, Val samples: {len(x_val_gru_nag)}, Test samples: {len(x_test_gru_nag)}')
# Out:
# Tuning sliding window on validation RMSE...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 30 -> validation RMSE: 4.3162
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 60 -> validation RMSE: 4.3772
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window= 90 -> validation RMSE: 4.6949
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#   window=120 -> validation RMSE: 4.8620
#
# Selected sliding window: 30 (validation RMSE: 4.3162)
# Data preparation completed.
# Train samples: 1834, Val samples: 369, Test samples: 369

# %%
# Visualize sliding window tuning results
window_df = pd.DataFrame(window_tuning_results_gru_nag, columns=['Window Size', 'Validation RMSE'])
plt.figure(figsize=(8, 4))
plt.bar(window_df['Window Size'].astype(str), window_df['Validation RMSE'], color='steelblue')
plt.axhline(best_window_val_rmse_gru_nag, color='crimson', linestyle='--', label=f'Best: {best_window_size_gru_nag}')
plt.title('Sliding Window Hyperparameter Tuning — GRU NAG')
plt.xlabel('Lookback Window (days)')
plt.ylabel('Validation RMSE ($)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 3: Building the LSTM and GRU Models

# %%
# Function to build the model
def build_model(model_type, optimizer, window_size):
    model = Sequential()
    if model_type == 'LSTM':
        model.add(LSTM(64, return_sequences=True, input_shape=(window_size, 1)))
        model.add(Dropout(0.2))
        model.add(LSTM(32, return_sequences=False))
        model.add(Dropout(0.2))
    elif model_type == 'GRU':
        model.add(GRU(64, return_sequences=True, input_shape=(window_size, 1)))
        model.add(Dropout(0.2))
        model.add(GRU(32, return_sequences=False))
        model.add(Dropout(0.2))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

print('Model building function defined.')
# Out:
# Model building function defined.

# %% [markdown]
# ## Step 4: Training Models and Evaluating Performance

# %% [markdown]
# **Training LSTM with Adam**

# %%
# LSTM with Adam
optimizer_adam = Adam(learning_rate=0.001)
model_lstm_adam = build_model('LSTM', optimizer_adam, best_window_size_lstm_adam)
history_lstm_adam = model_lstm_adam.fit(
    x_train_lstm_adam, y_train_lstm_adam,
    validation_data=(x_val_lstm_adam, y_val_lstm_adam),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    # callbacks=training_callbacks,
    verbose=1
)
print('LSTM with Adam training completed.')
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0321 - val_loss: 0.0500
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0069 - val_loss: 0.0425
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0056 - val_loss: 0.0401
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0059 - val_loss: 0.0378
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0052 - val_loss: 0.0361
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0048 - val_loss: 0.0368
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0043 - val_loss: 0.0337
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0039 - val_loss: 0.0368
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0037 - val_loss: 0.0348
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0038 - val_loss: 0.0305
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0038 - val_loss: 0.0297
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0036 - val_loss: 0.0292
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0045 - val_loss: 0.0307
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0032 - val_loss: 0.0286
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0033 - val_loss: 0.0279
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031 - val_loss: 0.0269
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031 - val_loss: 0.0287
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0031 - val_loss: 0.0262
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0029 - val_loss: 0.0289
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0033 - val_loss: 0.0258
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031 - val_loss: 0.0246
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0035 - val_loss: 0.0277
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030 - val_loss: 0.0265
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0023 - val_loss: 0.0250
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0029 - val_loss: 0.0253
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - val_loss: 0.0235
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0246
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030 - val_loss: 0.0228
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0022 - val_loss: 0.0219
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0025 - val_loss: 0.0219
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0022 - val_loss: 0.0213
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022 - val_loss: 0.0211
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0023 - val_loss: 0.0213
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0023 - val_loss: 0.0216
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0025 - val_loss: 0.0228
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0023 - val_loss: 0.0201
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0023 - val_loss: 0.0203
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - val_loss: 0.0206
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0023 - val_loss: 0.0218
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - val_loss: 0.0193
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022 - val_loss: 0.0194
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 0.0188
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - val_loss: 0.0190
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 0.0193
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0018 - val_loss: 0.0201
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0023 - val_loss: 0.0186
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 0.0181
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 0.0186
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0017 - val_loss: 0.0177
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - val_loss: 0.0181
# LSTM with Adam training completed.

# %% [markdown]
# **Training LSTM with Nesterov (NAG)**

# %%
# LSTM with Nesterov
optimizer_nag = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model_lstm_nag = build_model('LSTM', optimizer_nag, best_window_size_lstm_nag)
history_lstm_nag = model_lstm_nag.fit(
    x_train_lstm_nag, y_train_lstm_nag,
    validation_data=(x_val_lstm_nag, y_val_lstm_nag),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    # callbacks=training_callbacks,
    verbose=1
)
print('LSTM with Nesterov training completed.')
# Out:
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0394 - val_loss: 0.0551
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - val_loss: 0.0471
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - val_loss: 0.0449
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - val_loss: 0.0466
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - val_loss: 0.0441
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - val_loss: 0.0428
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - val_loss: 0.0417
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 0.0420
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0411
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - val_loss: 0.0411
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0409
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0404
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0391
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - val_loss: 0.0412
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - val_loss: 0.0382
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 0.0400
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 0.0399
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.0361
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - val_loss: 0.0360
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0368
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 0.0360
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 0.0364
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0363
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037 - val_loss: 0.0356
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038 - val_loss: 0.0362
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 0.0364
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - val_loss: 0.0352
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - val_loss: 0.0334
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0342
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0338
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0338
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 0.0331
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 0.0342
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 0.0328
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - val_loss: 0.0322
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - val_loss: 0.0326
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - val_loss: 0.0317
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - val_loss: 0.0339
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0327
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0314
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - val_loss: 0.0341
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0323
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - val_loss: 0.0308
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 0.0305
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0315
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0317
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - val_loss: 0.0311
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - val_loss: 0.0310
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 0.0312
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - val_loss: 0.0318
# LSTM with Nesterov training completed.

# %% [markdown]
# **Training GRU with Adam**

# %%
# GRU with Adam
optimizer_adam_gru = Adam(learning_rate=0.001)
model_gru_adam = build_model('GRU', optimizer_adam_gru, best_window_size_gru_adam)
history_gru_adam = model_gru_adam.fit(
    x_train_gru_adam, y_train_gru_adam,
    validation_data=(x_val_gru_adam, y_val_gru_adam),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    # callbacks=training_callbacks,
    verbose=1
)
print('GRU with Adam training completed.')
# Out:
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0390 - val_loss: 0.0242
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0062 - val_loss: 0.0209
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058 - val_loss: 0.0208
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 0.0213
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 0.0210
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - val_loss: 0.0208
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - val_loss: 0.0192
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - val_loss: 0.0203
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - val_loss: 0.0201
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 0.0178
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - val_loss: 0.0174
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 0.0170
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 0.0167
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - val_loss: 0.0169
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - val_loss: 0.0163
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0032 - val_loss: 0.0164
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0162
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0029 - val_loss: 0.0161
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - val_loss: 0.0160
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0026 - val_loss: 0.0155
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0025 - val_loss: 0.0157
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031 - val_loss: 0.0154
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027 - val_loss: 0.0152
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0151
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0024 - val_loss: 0.0148
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0029 - val_loss: 0.0146
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - val_loss: 0.0144
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022 - val_loss: 0.0143
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 0.0146
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - val_loss: 0.0147
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - val_loss: 0.0143
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022 - val_loss: 0.0138
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025 - val_loss: 0.0137
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - val_loss: 0.0139
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - val_loss: 0.0143
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - val_loss: 0.0138
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - val_loss: 0.0138
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - val_loss: 0.0138
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0020 - val_loss: 0.0139
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - val_loss: 0.0136
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 0.0135
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019 - val_loss: 0.0138
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - val_loss: 0.0138
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 0.0135
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - val_loss: 0.0133
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - val_loss: 0.0133
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0020 - val_loss: 0.0135
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0018 - val_loss: 0.0129
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0019 - val_loss: 0.0130
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0019 - val_loss: 0.0128
# GRU with Adam training completed.

# %% [markdown]
# **Training GRU with Nesterov (NAG)**

# %%
# GRU with Nesterov
optimizer_nag_gru = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model_gru_nag = build_model('GRU', optimizer_nag_gru, best_window_size_gru_nag)
history_gru_nag = model_gru_nag.fit(
    x_train_gru_nag, y_train_gru_nag,
    validation_data=(x_val_gru_nag, y_val_gru_nag),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    # callbacks=training_callbacks,
    verbose=1
)
print('GRU with Nesterov training completed.')
# Out:
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0524 - val_loss: 0.0199
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - val_loss: 0.0211
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - val_loss: 0.0200
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054 - val_loss: 0.0218
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - val_loss: 0.0197
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - val_loss: 0.0212
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - val_loss: 0.0197
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0222
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 0.0204
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 0.0209
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 0.0197
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - val_loss: 0.0196
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0196
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - val_loss: 0.0195
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - val_loss: 0.0203
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - val_loss: 0.0193
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0210
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039 - val_loss: 0.0194
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - val_loss: 0.0195
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - val_loss: 0.0197
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - val_loss: 0.0199
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - val_loss: 0.0199
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - val_loss: 0.0196
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0203
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039 - val_loss: 0.0198
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 0.0200
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0191
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - val_loss: 0.0191
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 0.0195
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - val_loss: 0.0193
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - val_loss: 0.0196
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - val_loss: 0.0192
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 0.0190
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - val_loss: 0.0193
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - val_loss: 0.0190
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0191
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0189
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0188
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - val_loss: 0.0197
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0187
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0188
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0196
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0186
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - val_loss: 0.0190
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 0.0188
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - val_loss: 0.0191
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0188
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0187
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - val_loss: 0.0191
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - val_loss: 0.0196
# GRU with Nesterov training completed.

# %% [markdown]
# ##Step 4: Making Predictions and Evaluating Models

# %%
# Makes predictions with each model
def make_predictions(model, x_data, adaptive_avg, adaptive_std, adaptive_gate):
    predictions = model.predict(x_data, verbose=0)
    result = inverse_dain(predictions, adaptive_avg, adaptive_std, adaptive_gate)
    return result

y_test_actual_lstm_adam = inverse_dain(y_test_lstm_adam, test_adaptive_avg, test_adaptive_std, test_gate)
y_test_actual_lstm_nag = inverse_dain(y_test_lstm_nag, test_adaptive_avg, test_adaptive_std, test_gate)
y_test_actual_gru_adam = inverse_dain(y_test_gru_adam, test_adaptive_avg, test_adaptive_std, test_gate)
y_test_actual_gru_nag = inverse_dain(y_test_gru_nag, test_adaptive_avg, test_adaptive_std, test_gate)

pred_lstm_adam = make_predictions(model_lstm_adam, x_test_lstm_adam, test_adaptive_avg, test_adaptive_std, test_gate)
pred_lstm_nag = make_predictions(model_lstm_nag, x_test_lstm_nag, test_adaptive_avg, test_adaptive_std, test_gate)
pred_gru_adam = make_predictions(model_gru_adam, x_test_gru_adam, test_adaptive_avg, test_adaptive_std, test_gate)
pred_gru_nag = make_predictions(model_gru_nag, x_test_gru_nag, test_adaptive_avg, test_adaptive_std, test_gate)

# Metrics in original price scale
rmse_lstm_adam = np.sqrt(mean_squared_error(y_test_actual_lstm_adam, pred_lstm_adam))
rmse_lstm_nag = np.sqrt(mean_squared_error(y_test_actual_lstm_nag, pred_lstm_nag))
rmse_gru_adam = np.sqrt(mean_squared_error(y_test_actual_gru_adam, pred_gru_adam))
rmse_gru_nag = np.sqrt(mean_squared_error(y_test_actual_gru_nag, pred_gru_nag))

mae_lstm_adam = mean_absolute_error(y_test_actual_lstm_adam, pred_lstm_adam)
mae_lstm_nag = mean_absolute_error(y_test_actual_lstm_nag, pred_lstm_nag)
mae_gru_adam = mean_absolute_error(y_test_actual_gru_adam, pred_gru_adam)
mae_gru_nag = mean_absolute_error(y_test_actual_gru_nag, pred_gru_nag)

r2_lstm_adam = r2_score(y_test_actual_lstm_adam, pred_lstm_adam)
r2_lstm_nag = r2_score(y_test_actual_lstm_nag, pred_lstm_nag)
r2_gru_adam = r2_score(y_test_actual_gru_adam, pred_gru_adam)
r2_gru_nag = r2_score(y_test_actual_gru_nag, pred_gru_nag)

metrics_values = {
    'LSTM Adam': {'RMSE': rmse_lstm_adam, 'MAE': mae_lstm_adam, 'R2': r2_lstm_adam},
    'LSTM NAG':  {'RMSE': rmse_lstm_nag,  'MAE': mae_lstm_nag,  'R2': r2_lstm_nag},
    'GRU Adam':  {'RMSE': rmse_gru_adam,  'MAE': mae_gru_adam,  'R2': r2_gru_adam},
    'GRU NAG':   {'RMSE': rmse_gru_nag,   'MAE': mae_gru_nag,   'R2': r2_gru_nag},
}

# Keep rmse_values for any later cells that still expect it
rmse_values = {name: m['RMSE'] for name, m in metrics_values.items()}

print('Predictions and metric calculations completed.')
for model_name, m in metrics_values.items():
    print(f"  {model_name}: RMSE = {m['RMSE']:.4f} | MAE = {m['MAE']:.4f} | R^2 = {m['R2']:.4f}")
# Out:
# Predictions and metric calculations completed.
#   LSTM Adam: RMSE = 3.8556 | MAE = 2.9986 | R^2 = 0.9496
#   LSTM NAG: RMSE = 5.0931 | MAE = 3.9811 | R^2 = 0.9121
#   GRU Adam: RMSE = 3.0760 | MAE = 2.3639 | R^2 = 0.9679
#   GRU NAG: RMSE = 3.9442 | MAE = 3.0556 | R^2 = 0.9473

# %%
# Ground truth vs prediction for every model
prediction_plots = [
    ('LSTM Adam', y_test_actual_lstm_adam, pred_lstm_adam),
    ('LSTM NAG',  y_test_actual_lstm_nag,  pred_lstm_nag),
    ('GRU Adam',  y_test_actual_gru_adam,  pred_gru_adam),
    ('GRU NAG',   y_test_actual_gru_nag,   pred_gru_nag),
]

fig, axes = plt.subplots(2, 2, figsize=(16, 10), sharex=False)
axes = axes.flatten()

for ax, (name, y_true, y_pred) in zip(axes, prediction_plots):
    ax.plot(y_true, label='Ground Truth', linewidth=1.5)
    ax.plot(y_pred, label='Prediction', linewidth=1.5, alpha=0.85)
    ax.set_title(name)
    ax.set_xlabel('Test Sample')
    ax.set_ylabel('Price')
    ax.legend()

plt.suptitle('Ground Truth vs Prediction (Test Set)', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 5: Visualizations and Analysis
# Visualizations included are:
# * Line Plot of Loss vs. Epochs
# * Line Plot of Log(Loss) vs. Epochs
# * Bar chart of Final loss by Model-Optimizer Combination
# * RMSE Summary table
# * Training and Validation Loss Heatmaps

# %% [markdown]
# **Line Plot of Loss vs. Epochs**

# %%
# Line Plot of Loss vs. Epochs
plt.figure(figsize=(14, 7))
plt.plot(history_lstm_adam.history['loss'], label='LSTM Adam')
plt.plot(history_lstm_nag.history['loss'], label='LSTM NAG')
plt.plot(history_gru_adam.history['loss'], label='GRU Adam')
plt.plot(history_gru_nag.history['loss'], label='GRU NAG')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

print("Loss vs. Epochs plot generated.")
# Out:
# Loss vs. Epochs plot generated.

# %%
# Convergence Curves
plt.figure(figsize=(14, 7))
plt.plot(np.log10(history_lstm_adam.history['loss']), label='LSTM Adam')
plt.plot(np.log10(history_lstm_nag.history['loss']), label='LSTM NAG')
plt.plot(np.log10(history_gru_adam.history['loss']), label='GRU Adam')
plt.plot(np.log10(history_gru_nag.history['loss']), label='GRU NAG')
plt.title('Log(Loss) vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Log(Loss)')
plt.legend()
plt.show()

print("Convergence curves generated.")
# Out:
# Convergence curves generated.

# %%
# Line Plot of Validation Loss vs. Epochs
plt.figure(figsize=(14, 7))
plt.plot(history_lstm_adam.history['val_loss'], label='LSTM Adam')
plt.plot(history_lstm_nag.history['val_loss'], label='LSTM NAG')
plt.plot(history_gru_adam.history['val_loss'], label='GRU Adam')
plt.plot(history_gru_nag.history['val_loss'], label='GRU NAG')
plt.title('Validation Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.show()

print("Validation Loss vs. Epochs plot generated.")
# Out:
# Validation Loss vs. Epochs plot generated.

# %% [markdown]
# **Bar Charts of Final Loss**

# %%
# Bar Chart of Final Loss
final_losses = [
    history_lstm_adam.history['loss'][-1],
    history_lstm_nag.history['loss'][-1],
    history_gru_adam.history['loss'][-1],
    history_gru_nag.history['loss'][-1]
]

models = ['LSTM Adam', 'LSTM NAG', 'GRU Adam', 'GRU NAG']

plt.figure(figsize=(10, 5))
plt.bar(models, final_losses, color=['blue', 'orange', 'green', 'red'])
plt.title('Final Loss by Model and Optimizer')
plt.xlabel('Model and Optimizer')
plt.ylabel('Final Loss')
plt.show()

print("Final Loss bar chart generated.")
# Out:
# Final Loss bar chart generated.

# %% [markdown]
# **Metrics Summary Table**

# %%
# Metrics Summary Table
metrics_table = [
    [model, f"{m['RMSE']:.4f}", f"{m['MAE']:.4f}", f"{m['R2']:.4f}"]
    for model, m in metrics_values.items()
]
print(tabulate(
    metrics_table,
    headers=['Model & Optimizer', 'RMSE', 'MAE', 'R^2'],
    tablefmt='pretty'
))

print("Metrics summary table generated.")
# Out:
# +-------------------+--------+--------+--------+
# | Model & Optimizer |  RMSE  |  MAE   |  R^2   |
# +-------------------+--------+--------+--------+
# |     LSTM Adam     | 3.8556 | 2.9986 | 0.9496 |
# |     LSTM NAG      | 5.0931 | 3.9811 | 0.9121 |
# |     GRU Adam      | 3.0760 | 2.3639 | 0.9679 |
# |      GRU NAG      | 3.9442 | 3.0556 | 0.9473 |
# +-------------------+--------+--------+--------+
# Metrics summary table generated.

# %% [markdown]
# **Heatmaps for summary**

# %%
# Extract loss and validation loss values automatically from training history
lstm_adam_loss = history_lstm_adam.history['loss']
lstm_adam_val_loss = history_lstm_adam.history['val_loss']

lstm_nag_loss = history_lstm_nag.history['loss']
lstm_nag_val_loss = history_lstm_nag.history['val_loss']

gru_adam_loss = history_gru_adam.history['loss']
gru_adam_val_loss = history_gru_adam.history['val_loss']

gru_nag_loss = history_gru_nag.history['loss']
gru_nag_val_loss = history_gru_nag.history['val_loss']

# %%
# Convert lists into a DataFrame (variable epoch count due to early stopping)
max_epoch_count = max(
    len(history_lstm_adam.history['loss']),
    len(history_lstm_nag.history['loss']),
    len(history_gru_adam.history['loss']),
    len(history_gru_nag.history['loss'])
)
epochs = np.arange(1, max_epoch_count + 1)
data = {
    'Epoch': epochs,
    'LSTM Adam Loss': lstm_adam_loss + [np.nan] * (max_epoch_count - len(lstm_adam_loss)),
    'LSTM NAG Loss': lstm_nag_loss + [np.nan] * (max_epoch_count - len(lstm_nag_loss)),
    'GRU Adam Loss': gru_adam_loss + [np.nan] * (max_epoch_count - len(gru_adam_loss)),
    'GRU NAG Loss': gru_nag_loss + [np.nan] * (max_epoch_count - len(gru_nag_loss)),
    'LSTM Adam Val Loss': lstm_adam_val_loss + [np.nan] * (max_epoch_count - len(lstm_adam_val_loss)),
    'LSTM NAG Val Loss': lstm_nag_val_loss + [np.nan] * (max_epoch_count - len(lstm_nag_val_loss)),
    'GRU Adam Val Loss': gru_adam_val_loss + [np.nan] * (max_epoch_count - len(gru_adam_val_loss)),
    'GRU NAG Val Loss': gru_nag_val_loss + [np.nan] * (max_epoch_count - len(gru_nag_val_loss)),
}
df_losses = pd.DataFrame(data)
df_losses
# Out:
#     Epoch  LSTM Adam Loss  LSTM NAG Loss  GRU Adam Loss  GRU NAG Loss  \
# 0       1        0.032073       0.039390       0.039039      0.052448
# 1       2        0.006879       0.007611       0.006163      0.007269
# 2       3        0.005618       0.006385       0.005751      0.005738
# 3       4        0.005868       0.006332       0.004152      0.005366
# 4       5        0.005219       0.005292       0.004227      0.005169
# 5       6        0.004789       0.005418       0.004420      0.005188
# 6       7        0.004262       0.005181       0.004116      0.004281
# 7       8        0.003920       0.004887       0.003568      0.004950
# 8       9        0.003674       0.004986       0.003469      0.004688
# 9      10        0.003829       0.004528       0.003414      0.004248
# 10     11        0.003809       0.004578       0.003182      0.004225
# 11     12        0.003605       0.004594       0.003392      0.004110
# 12     13        0.004520       0.004367       0.003408      0.004583
# 13     14        0.003234       0.003977       0.002796      0.003949
# 14     15        0.003250       0.004132       0.002818      0.003494
# 15     16        0.003136       0.003946       0.003182      0.003534
# 16     17        0.003131       0.003884       0.002817      0.003704
# 17     18        0.003115       0.004098       0.002858      0.003883
# 18     19        0.002855       0.003604       0.002791      0.003995
# 19     20        0.003331       0.003743       0.002580      0.004165
# 20     21        0.003069       0.003801       0.002487      0.004122
# 21     22        0.003467       0.003858       0.003063      0.003577
# 22     23        0.003002       0.003742       0.002739      0.003643
# 23     24        0.002340       0.003682       0.002824      0.003390
# 24     25        0.002943       0.003782       0.002366      0.003887
# 25     26        0.002643       0.003762       0.002918      0.003354
# 26     27        0.002769       0.003550       0.002226      0.004154
# 27     28        0.002953       0.003538       0.002191      0.003283
# 28     29        0.002196       0.003424       0.002012      0.003423
# 29     30        0.002549       0.003681       0.002412      0.003330
# 30     31        0.002247       0.003438       0.002418      0.003406
# 31     32        0.002245       0.003332       0.002216      0.003196
# 32     33        0.002297       0.003269       0.002494      0.003247
# 33     34        0.002252       0.003286       0.002134      0.003169
# 34     35        0.002512       0.003191       0.002098      0.002952
# 35     36        0.002294       0.003586       0.002572      0.003143
# 36     37        0.002337       0.003196       0.002433      0.003430
# 37     38        0.002589       0.003058       0.002301      0.003402
# 38     39        0.002301       0.003434       0.002016      0.003655
# 39     40        0.002586       0.003118       0.002138      0.003143
# 40     41        0.002191       0.003474       0.002004      0.003148
# 41     42        0.001955       0.003120       0.001944      0.003137
# 42     43        0.002116       0.002915       0.001754      0.003141
# 43     44        0.002017       0.003348       0.002009      0.002983
# 44     45        0.001801       0.003066       0.002089      0.003190
# 45     46        0.002311       0.003064       0.002164      0.002931
# 46     47        0.002042       0.002821       0.001980      0.003107
# 47     48        0.002009       0.002663       0.001847      0.003147
# 48     49        0.001731       0.003340       0.001881      0.003221
# 49     50        0.002093       0.002746       0.001860      0.003061
#
#     LSTM Adam Val Loss  LSTM NAG Val Loss  GRU Adam Val Loss  GRU NAG Val Loss
# 0             0.049987           0.055133           0.024193          0.019885
# 1             0.042539           0.047114           0.020908          0.021129
# 2             0.040139           0.044881           0.020772          0.020040
# 3             0.037759           0.046557           0.021312          0.021807
# 4             0.036148           0.044136           0.020972          0.019739
# 5             0.036819           0.042824           0.020758          0.021184
# 6             0.033712           0.041742           0.019153          0.019698
# 7             0.036847           0.042007           0.020309          0.022207
# 8             0.034843           0.041125           0.020115          0.020378
# 9             0.030466           0.041125           0.017801          0.020927
# 10            0.029700           0.040861           0.017396          0.019673
# 11            0.029164           0.040401           0.017045          0.019574
# 12            0.030656           0.039111           0.016663          0.019576
# 13            0.028641           0.041239           0.016903          0.019512
# 14            0.027930           0.038150           0.016277          0.020300
# 15            0.026871           0.039997           0.016358          0.019285
# 16            0.028669           0.039857           0.016230          0.020987
# 17            0.026205           0.036091           0.016106          0.019360
# 18            0.028934           0.035959           0.015983          0.019513
# 19            0.025790           0.036821           0.015539          0.019705
# 20            0.024551           0.035983           0.015673          0.019901
# 21            0.027707           0.036384           0.015439          0.019861
# 22            0.026543           0.036279           0.015221          0.019644
# 23            0.024956           0.035567           0.015087          0.020323
# 24            0.025276           0.036210           0.014765          0.019820
# 25            0.023507           0.036432           0.014622          0.020033
# 26            0.024571           0.035154           0.014362          0.019110
# 27            0.022780           0.033386           0.014340          0.019144
# 28            0.021880           0.034187           0.014576          0.019465
# 29            0.021874           0.033839           0.014691          0.019345
# 30            0.021263           0.033822           0.014310          0.019618
# 31            0.021059           0.033129           0.013805          0.019227
# 32            0.021262           0.034162           0.013746          0.018991
# 33            0.021590           0.032816           0.013925          0.019341
# 34            0.022765           0.032205           0.014322          0.019009
# 35            0.020144           0.032575           0.013811          0.019106
# 36            0.020341           0.031741           0.013751          0.018949
# 37            0.020579           0.033887           0.013804          0.018813
# 38            0.021799           0.032730           0.013882          0.019669
# 39            0.019318           0.031361           0.013567          0.018711
# 40            0.019403           0.034064           0.013454          0.018792
# 41            0.018846           0.032320           0.013776          0.019580
# 42            0.019000           0.030830           0.013807          0.018648
# 43            0.019349           0.030520           0.013476          0.018998
# 44            0.020113           0.031549           0.013338          0.018810
# 45            0.018589           0.031651           0.013319          0.019065
# 46            0.018142           0.031067           0.013517          0.018843
# 47            0.018576           0.030984           0.012865          0.018739
# 48            0.017727           0.031179           0.013005          0.019135
# 49            0.018107           0.031760           0.012803          0.019582

# %%
# Create heatmaps for loss values
plt.figure(figsize=(14, 10))

loss_cols = ['LSTM Adam Loss', 'LSTM NAG Loss', 'GRU Adam Loss', 'GRU NAG Loss']
val_cols = ['LSTM Adam Val Loss', 'LSTM NAG Val Loss', 'GRU Adam Val Loss', 'GRU NAG Val Loss']
epoch_labels = df_losses['Epoch'].astype(int).tolist()

plt.subplot(1, 2, 1)
sns.heatmap(
    df_losses[loss_cols].values,
    annot=True, cmap='viridis', fmt='.4f',
    xticklabels=['LSTM Adam', 'LSTM NAG', 'GRU Adam', 'GRU NAG'],
    yticklabels=epoch_labels
)
plt.title('Training Loss Heatmap')
plt.xlabel('Model')
plt.ylabel('Epoch')

plt.subplot(1, 2, 2)
sns.heatmap(
    df_losses[val_cols].values,
    annot=True, cmap='viridis', fmt='.4f',
    xticklabels=['LSTM Adam', 'LSTM NAG', 'GRU Adam', 'GRU NAG'],
    yticklabels=epoch_labels
)
plt.title('Validation Loss Heatmap')
plt.xlabel('Model')
plt.ylabel('Epoch')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Training Loss Histogram**

# %%
plt.figure(figsize=(14, 7))

# Training loss histogram
plt.subplot(1, 2, 1)
plt.hist(lstm_adam_loss, bins=10, alpha=0.5, label='LSTM Adam Training Loss')
plt.hist(lstm_nag_loss, bins=10, alpha=0.5, label='LSTM NAG Training Loss')
plt.hist(gru_adam_loss, bins=10, alpha=0.5, label='GRU Adam Training Loss')
plt.hist(gru_nag_loss, bins=10, alpha=0.5, label='GRU NAG Training Loss')
plt.title('Training Loss Distribution')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.legend()

# Validation loss histogram
plt.subplot(1, 2, 2)
plt.hist(lstm_adam_val_loss, bins=10, alpha=0.5, label='LSTM Adam Validation Loss')
plt.hist(lstm_nag_val_loss, bins=10, alpha=0.5, label='LSTM NAG Validation Loss')
plt.hist(gru_adam_val_loss, bins=10, alpha=0.5, label='GRU Adam Validation Loss')
plt.hist(gru_nag_val_loss, bins=10, alpha=0.5, label='GRU NAG Validation Loss')
plt.title('Validation Loss Distribution')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()
